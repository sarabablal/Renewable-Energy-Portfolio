# %%
# install pandas & requests liberaries
# !pip install numpy
# !mamba install pandas
# !mamba install requests
# Out:
# mambajs 0.21.4
#
# Process pip requirements ...
#
# Requirement numpy already handled by conda/micromamba/mamba.
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, requests
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 12.084 seconds
# All requested packages already installed.
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, requests
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 9.394 seconds
# All requested packages already installed.

# %%
# importing pandas & requests liberaries
import numpy
import pandas as pd
import requests

# %%
# target geogrphical coordinates (ouarzazate, morocco)
lat, lon = 30.93, -6.91 

# Open-Meteo API endpoint for real-time solar and wind parameters
url = f"https://api.open-meteo.com/v1/forecast?latitude={lat}&longitude={lon}&current_weather=true"

# %%
# sending HTTP GET Request to retrieve weather data
response = requests.get(url)

print(response.status_code)
# Out:
# 200

# %%
# parse JSON response into a Python dictionary
data = response.json ()

print (data.keys())
# Out:
# dict_keys(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'current_weather_units', 'current_weather'])

# %%
# extract the current weather object
current = data ['current_weather']
print (current)
# Out:
# {'time': '2026-08-30T20:00', 'interval': 900, 'temperature': 33.8, 'windspeed': 8.7, 'winddirection': 83, 'is_day': 0, 'weathercode': 3}

# %%
# package relevant physical parameters for PV & Wind Turbine modeling
data_dict = {
    'timestamp' : current ['time'],            # Measurement timestamp
    'temperature': current['temperature'],     # Temperature in °C
    'wind_speed' : current ['windspeed'],      # Wind speed in km/h
    'wind_degree' : current ['winddirection'],
    'weather_code' : current ['weathercode']
}

# %%
df = pd.DataFrame([data_dict])
print (df)
# Out:
#           timestamp  wind_speed  wind_degree  weather_code
# 0  2026-08-30T19:15         9.8          114             3

# %%
df.to_csv ('weather_data.csv', mode= 'a', index=False)
